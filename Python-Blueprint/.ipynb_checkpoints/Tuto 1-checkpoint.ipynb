# %%
import requests
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
r = requests.get(r"https://api.github.com/users/acombs/starred")
r.json()
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:122: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ...

# %%
os.getcwd()
# Out:
# '/home/jaafar/anaconda2/Forecasting-ANN/Untitled Folder'

# %%
file = !ls .. | grep PCA

# %%
file
# Out:
# ['PCA.ipynb']

# %%
PATH = r'/home/jaafar/anaconda2/Forecasting-ANN/Python-Blueprint/data/'

# %%
r = requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:122: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
with open(PATH + 'iris.data','w') as f:
    f.write(r.text)

# %%
os.chdir(PATH)

# %%
df = pd.read_csv(PATH + 'iris.data', names=['sepal length','sepal width','petal length','petal width','Class'])

# %%
df.head()
# Out:
#    sepal length  setal width  petal length  petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# df.ix[:number_of_rows,:number_of_columns]
df.ix[:3,:2]
# Out:
#    sepal length    B
# 0           5.1  3.5
# 1           4.9  3.0
# 2           4.7  3.2
# 3           4.6  3.1

# %%
df.ix[:3, [x for x in df.columns if 'petal' in x]]
# Out:
#    petal length  petal width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2

# %%
df['Class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df[df['Class']=='Iris-virginica'].head()
# Out:
#      sepal length  setal width  petal length  petal width           Class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica

# %%
df.count()
# Out:
# sepal length    150
# setal width     150
# petal length    150
# petal width     150
# Class           150
# dtype: int64

# %%
df[df['Class']=='Iris-setosa'].count()
# Out:
# sepal length    50
# setal width     50
# petal length    50
# petal width     50
# Class           50
# dtype: int64

# %%
virginica = df[df['Class']=='Iris-virginica'].reset_index(drop=True)

# %%
virginica.head()
# Out:
#    sepal length  setal width  petal length  petal width           Class
# 0           6.3          3.3           6.0          2.5  Iris-virginica
# 1           5.8          2.7           5.1          1.9  Iris-virginica
# 2           7.1          3.0           5.9          2.1  Iris-virginica
# 3           6.3          2.9           5.6          1.8  Iris-virginica
# 4           6.5          3.0           5.8          2.2  Iris-virginica

# %%
df[(df['Class']=='Iris-virginica')&(df['petal width']>2.2)]
# Out:
#      sepal length  setal width  petal length  petal width           Class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# ...

# %%
df.describe()
# Out:
#        sepal length  setal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe(percentiles=[.20,.70,.95])
# Out:
#        sepal length  setal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 20%        5.000000     2.700000      1.500000     0.200000
# 50%        5.800000     3.000000      4.350000     1.300000
# 70%        6.300000     3.200000      5.000000     1.800000
# 95%        7.255000     3.800000      6.100000     2.300000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.corr()
# Out:
#               sepal length  setal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# setal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
df.corr(method='kendall')
# Out:
#               sepal length  setal width  petal length  petal width
# sepal length      1.000000    -0.072112      0.717624     0.654960
# setal width      -0.072112     1.000000     -0.182391    -0.146988
# petal length      0.717624    -0.182391      1.000000     0.803014
# petal width       0.654960    -0.146988      0.803014     1.000000

# %% [markdown]
# ### Matplotlib

# %%
fig, ax = plt.subplots(2,2,figsize=(6,4))
ax[0][0].hist(df['sepal length'],color='black')
ax[0][0].set_xlabel('width',fontsize=12)
ax[0][0].set_ylabel('count',fontsize=12)
ax[0][0].set_title('Iris sepal length', fontsize=13,y=1.1)

ax[1][0].scatter(df['sepal length'],df['setal width'],color='green')
ax[1][0].set_xlabel('width',fontsize=12)
ax[1][0].set_ylabel('count',fontsize=12)
ax[1][0].set_title('Iris sepal length', fontsize=13,y=1.1)

ax[1][1].plot(df['sepal length'],color='green')
ax[1][1].set_xlabel('width',fontsize=12)
ax[1][1].set_ylabel('count',fontsize=12)
ax[1][1].set_title('Iris sepal length', fontsize=13,y=1.1)


plt.tight_layout()

# %%
sns.pairplot(df,hue='Class')

# %%
df['petal area'] = df.apply(lambda r: r['petal length']*2, axis=1)

# %%
df.head()
# Out:
#    sepal length  setal width  petal length  petal width        Class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    petal area
# 0         2.8
# 1         2.8
# 2         2.6
# 3         3.0
# 4         2.8

# %%
df.applymap(lambda v: np.log(v) if isinstance(v,float) else v).head()
# Out:
#    sepal length  setal width  petal length  petal width        Class  \
# 0      1.629241     1.252763      0.336472    -1.609438  Iris-setosa
# 1      1.589235     1.098612      0.336472    -1.609438  Iris-setosa
# 2      1.547563     1.163151      0.262364    -1.609438  Iris-setosa
# 3      1.526056     1.131402      0.405465    -1.609438  Iris-setosa
# 4      1.609438     1.280934      0.336472    -1.609438  Iris-setosa
#
#    petal area
# 0    1.029619
# 1    1.029619
# 2    0.955511
# 3    1.098612
# 4    1.029619

# %%
df.groupby('Class').describe()
# Out:
#                        petal area  petal length  petal width  sepal length  \
# Class
# Iris-setosa     count   50.000000     50.000000    50.000000     50.000000
#                 mean     2.928000      1.464000     0.244000      5.006000
#                 std      0.347022      0.173511     0.107210      0.352490
#                 min      2.000000      1.000000     0.100000      4.300000
#                 25%      2.800000      1.400000     0.200000      4.800000
#                 50%      3.000000      1.500000     0.200000      5.000000
#                 75%      3.150000      1.575000     0.300000      5.200000
#                 max      3.800000      1.900000     0.600000      5.800000
# Iris-versicolor count   50.000000     50.000000    50.000000     50.000000
#                 mean     8.520000      4.260000     1.326000      5.936000
#                 std      0.939822      0.469911     0.197753      0.516171
# ...

# %%
df.groupby('petal width')['Class'].unique().to_frame()
# Out:
#                                          Class
# petal width
# 0.1                              [Iris-setosa]
# 0.2                              [Iris-setosa]
# 0.3                              [Iris-setosa]
# 0.4                              [Iris-setosa]
# 0.5                              [Iris-setosa]
# 0.6                              [Iris-setosa]
# 1.0                          [Iris-versicolor]
# 1.1                          [Iris-versicolor]
# 1.2                          [Iris-versicolor]
# 1.3                          [Iris-versicolor]
# 1.4          [Iris-versicolor, Iris-virginica]
# 1.5          [Iris-versicolor, Iris-virginica]
# 1.6          [Iris-versicolor, Iris-virginica]
# 1.7          [Iris-versicolor, Iris-virginica]
# 1.8          [Iris-versicolor, Iris-virginica]
# 1.9                           [Iris-virginica]
# 2.0                           [Iris-virginica]
# 2.1                           [Iris-virginica]
# 2.2                           [Iris-virginica]
# ...

# %%
df.groupby("Class")['petal width'].agg({'delta':lambda x: x.max()-x.min(),'max':lambda x: x.max(),'min':lambda x: x.min()})
# Out:
#                  max  min  delta
# Class
# Iris-setosa      0.6  0.1    0.5
# Iris-versicolor  1.8  1.0    0.8
# Iris-virginica   2.5  1.4    1.1

# %%
df.tail()
# Out:
#      sepal length  setal width  petal length  petal width           Class  \
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal area
# 145        10.4
# 146        10.0
# 147        10.4
# 148        10.8
# 149        10.2

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.scatter(df['sepal length'],df['setal width'],color='green')
ax.set_xlabel('width',fontsize=12)
ax.set_ylabel('count',fontsize=12)
ax.set_title('Iris sepal length', fontsize=13,y=1.1)

# %%
'''
This is not working : import statsmodel.api as sm

'''
from statsmodels import api as sm

# %%
y = df['sepal length'][:50]
x = df['sepal width'][:50]
X = sm.add_constant(x)

# %%
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           sepal length   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     60.52
# Date:                Thu, 06 Oct 2016   Prob (F-statistic):           4.75e-10
# Time:                        18:07:30   Log-Likelihood:                 2.0879
# No. Observations:                  50   AIC:                           -0.1759
# Df Residuals:                      48   BIC:                             3.648
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const           2.6447      0.305      8.660      0.000         2.031     3.259
# ...

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x, results.fittedvalues, label='regression line')
ax.scatter(df['sepal length'],df['setal width'],color='green')
ax.set_xlabel('width',fontsize=12)
ax.set_ylabel('count',fontsize=12)
ax.set_title('Iris sepal length', fontsize=13,y=1.1)
