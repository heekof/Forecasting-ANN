# %%
import datetime
import time

# Import libraries use for visualization and analysis
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import cufflinks as cf

# Import the Monasca and Keystone clients
from monascaclient import client
from monascaclient import ksclient

from pandas import Series,DataFrame

# Import library to execute remote commands for monasca-agent demo
import spur
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''%export OS_PROJECT_NAME=mini-mon
# %export OS_PASSWORD=password
# %export OS_AUTH_URL=http://157.159.232.218:35357/v3/
# %export OS_USERNAME=mini-mon
# %export MONASCA_API_URL=http://157.159.232.217:8070/v2.0/'''
monasca_url = 'http://157.159.232.217:8070/v2.0/'

# %%
api_version = '2_0'

# Authenticate to Keystone
keystone_url = 'http://157.159.232.218:35357/v3/'
ks = ksclient.KSClient(auth_url=keystone_url, username='mini-mon', password='password')

# construct the mon client
monasca_client = client.Client(api_version, monasca_url, token=ks.token)
# call the metric-create command
'''
dimensions = {'instance_id': '12345', 'service': 'hello'}
fields = {}
fields['name'] = 'cindy1'
fields['dimensions'] = dimensions
fields['timestamp'] = time.time()
fields['value'] = 222.333'''
# Out:
# "\ndimensions = {'instance_id': '12345', 'service': 'hello'}\nfields = {}\nfields['name'] = 'cindy1'\nfields['dimensions'] = dimensions\nfields['timestamp'] = time.time()\nfields['value'] = 222.333"

# %%
try:
    resp = monasca_client.metrics.list();   
except exc.HTTPException as he:
    print(he.code)
    print(he.message)
else:
    print(resp)

# %%
#monasca_client.metrics.list_measurements('2014-01-01T00:00:00Z');

# %%
shell = spur.SshShell(hostname='157.159.232.217',username='ubuntu',missing_host_key=spur.ssh.MissingHostKey.accept,private_key_file='/home/jaafar/Downloads/ici.pem');

# %%
# for testing
T = shell.run(["ifconfig"])

# %%
#T = shell.run(["monasca","measurement-list","cpu.user_perc", "2016-05-20T15:52:26.0C"])

# %%
#result = shell.run(["export", "OS_PROJECT_NAME=mini-mon"])#,["export", "OS_PASSWORD=password"],["export", "OS_AUTH_URL=http://157.159.232.218:35357/v3"],["export", "OS_USERNAME=mini-mon"])#
print(result.output) # prints hello
# Out:
# hello

# %%
#result = shell.run(["monasca","metric-list"])
#print(result.output) # prints hello

# %%
# sync clock
# shell.run(['sudo', 'ntpdate', 'time.nist.gov'])

# %%
def get_metrics(names=[None], dimensions={}, limit=10):
    metrics = []
    for name in names:        
        # Invoke the Monasca client
        metrics = metrics + monasca_client.metrics.list(name=name, dimensions=dimensions, limit=limit)
    return metrics

# %%
def get_measurements(metrics, start_time = None, end_time = None, limit=None):
    measurements = []
    
    if start_time == None:
        start_date = datetime.datetime.utcnow() - datetime.timedelta(seconds=3600)
        start_time = start_date.strftime("%Y-%m-%dT%H:%M:%SZ")

    if end_time == None:
        end_date = datetime.datetime.utcnow() - datetime.timedelta(seconds=0)
        end_time = end_date.strftime("%Y-%m-%dT%H:%M:%SZ")
        
    for metric in metrics:        
        # Invoke the Monasca client
        measurements.append(monasca_client.metrics.list_measurements(
                name=metric['name'],
                dimensions=metric['dimensions'],
                start_time=start_time,
                end_time=end_time))
        
    return measurements

# %%
def df_from_measurements(measurements, group_by=[]):
    '''Returns a DataFrame given measurements'''
    measurement = measurements[1]
    m = np.array(measurement[0]['measurements'])  
    timestamps = m[:, measurement[0]['columns'].index('timestamp')]
    df = pd.DataFrame(index = timestamps)  
    
    for measurement in measurements:
        if measurement:
            measure = measurement
            m = np.array(measure[0]['measurements'])
            name = measure[0]['name']
            dimensions = measure[0]['dimensions']
        
            for group in group_by:
                if group in dimensions:
                    name += '.' + dimensions[group]
            #df[name] = m[:measure[1][0]['columns'].index('value')]     
    return df

# %%
metrics = get_metrics(names=['net.out_packets_sec'])
measurements = get_measurements(metrics,"2016-05-12T15:52:26.0Z","2016-05-14T15:55:26.0Z")

# %%
i = 0;
max = len(measurements);
for measure in measurements:
    if measure:
       
        data = np.array(measure[0]['measurements'])
        metric_name = measure[0]['name']
        hostname = measure[0]['dimensions'].get('hostname')
        service = measure[0]['dimensions'].get('service')
        timestamp = ["" for x in range(len(data))] 
        values = np.zeros(len(data))
        i = i + 1;
        i=0;
        if hostname == "jaafar" and metric_name == "net.out_packets_sec":
            for d in data:
                timestamp[i] = d[0]
                values[i] = d[1]
                i = i + 1
            df = pd.DataFrame(index = timestamp)
            df['name'] = metric_name
            df[service] = service
            df[hostname] = hostname
            df['valeur'] = values
            df['time'] = np.arange(len(timestamp))

# %%
,'net.out_packets_sec.value'
# Out:
# "'net.out_packets_sec.value'"

# %%
metrics
# Out:
# [{u'dimensions': {u'device': u'eth0',
#    u'hostname': u'devstack',
#    u'service': u''},
#   u'id': u'0',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'virbr0',
#    u'hostname': u'devstack',
#    u'service': u''},
#   u'id': u'1',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'eth0',
#    u'hostname': u'mini-mon',
#    u'service': u'monitoring'},
#   u'id': u'2',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'eth0',
#    u'hostname': u'devstack2',
#    u'service': u'client-str'},
#   u'id': u'3',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'eth0',
#    u'hostname': u'opendaylight',
#    u'service': u'opendaylight'},
#   u'id': u'4',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'virbr0',
#    u'hostname': u'jaafar',
#    u'service': u''},
#   u'id': u'5',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'wlan0',
#    u'hostname': u'jaafar',
#    u'service': u''},
#   u'id': u'6',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'eth0', u'hostname': u'jaafar', u'service': u''},
#   u'id': u'7',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'eth0',
#    u'hostname': u'ns343875.ip-94-23-33.eu',
#    u'service': u'streaming-testbed'},
#   u'id': u'8',
#   u'name': u'net.out_packets_sec'},
#  {u'dimensions': {u'device': u'vboxnet0',
#    u'hostname': u'ns343875.ip-94-23-33.eu',
#    u'service': u'streaming-testbed'},
#   u'id': u'9',
#   u'name': u'net.out_packets_sec'}]

# %%
df
# Out:
#                                          name  monitoring  mini-mon    valeur  \
# 2016-05-12T15:52:35.000Z  net.out_packets_sec  monitoring  mini-mon  5.200000
# 2016-05-12T15:52:50.000Z  net.out_packets_sec  monitoring  mini-mon  5.800000
# 2016-05-12T15:53:05.000Z  net.out_packets_sec  monitoring  mini-mon  5.066667
# 2016-05-12T15:53:20.000Z  net.out_packets_sec  monitoring  mini-mon  5.266667
# 2016-05-12T15:53:35.000Z  net.out_packets_sec  monitoring  mini-mon  4.600000
# 2016-05-12T15:53:50.000Z  net.out_packets_sec  monitoring  mini-mon  5.666667
# 2016-05-12T15:59:50.000Z    28
# ...                        ...
# 2016-05-14T09:27:13.000Z  9970
# 2016-05-14T09:27:28.000Z  9971
# 2016-05-14T09:27:43.000Z  9972
# 2016-05-14T09:27:58.000Z  9973
# 2016-05-14T09:28:13.000Z  9974
# 2016-05-14T09:28:28.000Z  9975
# 2016-05-14T09:28:43.000Z  9976
# 2016-05-14T09:28:58.000Z  9977
# 2016-05-14T09:29:13.000Z  9978
# 2016-05-14T09:29:28.000Z  9979
# 2016-05-14T09:29:43.000Z  9980
# 2016-05-14T09:29:58.000Z  9981
# 2016-05-14T09:30:13.000Z  9982
# 2016-05-14T09:30:28.000Z  9983
# 2016-05-14T09:30:43.000Z  9984
# 2016-05-14T09:30:58.000Z  9985
# 2016-05-14T09:31:13.000Z  9986
# 2016-05-14T09:31:28.000Z  9987
# 2016-05-14T09:31:43.000Z  9988
# 2016-05-14T09:31:58.000Z  9989
# 2016-05-14T09:32:13.000Z  9990
# 2016-05-14T09:32:28.000Z  9991
# 2016-05-14T09:32:43.000Z  9992
# 2016-05-14T09:32:58.000Z  9993
# 2016-05-14T09:33:14.000Z  9994
# 2016-05-14T09:33:29.000Z  9995
# 2016-05-14T09:33:44.000Z  9996
# 2016-05-14T09:33:59.000Z  9997
# 2016-05-14T09:34:14.000Z  9998
# 2016-05-14T09:34:29.000Z  9999
#
# [10000 rows x 5 columns]

# %%
sns.lmplot('time','valeur',df,order=2,scatter_kws={'marker':'o','color':'indianred'},line_kws={'linewidth':1,'color':'blue'})

# %% [markdown]
# ## Start from Here the Evaluation

# %%
v = np.asarray(df.valeur)
X_mean = np.asarray(pd.rolling_mean(df['valeur'],5))
X = v[1:300]
df_slice = df[1:300];
df_slice;

# %%
def write_to_csv(filename,df): 
    dframe = DataFrame(df,columns=['valeur'])
    dframe.to_csv(filename,sep=';',index=False,header=None)

# %%
write_to_csv('jaafar.csv',df)

# %%
# Plot the selected sub range in function of time 
tmps =np.arange(X.size)
plt.subplots(figsize=(30, 10))
plt.plot(tmps,X,color='indianred',alpha=0.5)

# %%
# We'll use pct_change to find the percent change for each day
df_slice['perc_change'] = df_slice['valeur'].pct_change()
# Then we'll plot the daily return percentage
df_slice['valeur'].plot(figsize=(16,6),legend=True,linestyle='--',marker='o')

df_slice['perc_change'].plot(figsize=(16,6),legend=True,linestyle='-',marker='x')
# Out:
# /home/jaafar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# set the variable percentage change to se if learning is better using it instead of norm
perc_change = np.asarray(df_slice['perc_change']);

# %%
perc_change;

# %%
ma_pt = [2,5]

for ma in ma_pt:
    column_name = "MA for %s datapoint" %(str(ma))
    df_slice[column_name]=pd.rolling_mean(df_slice['valeur'],ma)
# Out:
# /home/jaafar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_slice[['valeur','MA for 5 datapoint']].plot(subplots=True,figsize=(20,5),)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fef60848650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fef60710ad0>], dtype=object)

# %%
def normalize(X):
    xmin = X.min()
    xmax = X.max()
    x2 = X.copy()
    x2 -= xmin
    x2 /= (xmax-xmin)
    return x2,(xmax-xmin),xmin

# %%
[X_norm,normx,normy] = normalize(X)

# %%
def structure_data(X,window):
    y = X[window:]
    y_l = [ [y[i]] for i in range(y.size) ]
    X_input =  np.resize(X,(X.size/window,window))
    X_l = X_input.tolist()
    return X_l,y_l,y

# %%
window = 15
[X,y,y_arr] = structure_data(X_norm,window)

# %%
from ann import ANN

# 4 input neurons: sepal length (cm),sepal width (cm), petal length (cm), petal width (cm)
# 10 hidden neurons
# 3 output neurons: setosa [1, 0, 0], versicolor [0, 1, 0], virginica [0, 0, 1]
nn = ANN([10,23,1], activation_fun='tanh')


# Here please Try to represent the input data as percentage so that you can capture patterns

# train the ANN
#nn.train(inputs, targets, 1600)
nn.train(X,y,500)
# Out:
# (0, nan)
# (100, nan)
# (200, nan)
# (300, nan)
# (400, nan)

# %%
def get_prediction(X):
     return [ nn.predict(X[i])[0]*normx+normy for i in range(len(X))]

# %%
h = get_prediction(X)

# %%
def unnorm(y_arr2):
    for i in range(y_arr2.size):
        y_arr2[i] = y_arr2[i] * normx+normy 
    return y_arr2

# %%
y_arr_N = np.zeros(y_arr.size)
y_arr_N = unnorm(y_arr)

# %%
y_arr_N
# Out:
# array([ 27.36444444,  25.78666667,  24.52444444,  29.25777778,
#         27.68      ,  24.20888889,  31.15111111,  24.20888889,
#         31.46666667,  23.57777778,  24.84      ,  27.99555556,
#         25.78666667,  23.57777778,  34.93777778,  28.31111111,
#         30.52      ,  23.89333333,  31.78222222,  22.59166667,
#         30.20444444,  23.26222222,  29.88888889,  29.88888889,
#         28.31111111,  30.52      ,  24.52444444,  30.20444444,
#         26.41777778,  29.57333333,  25.47111111,  30.83555556,
#         25.47111111,  28.31111111,  25.78666667,  24.84      ,
#         30.52      ,  26.10222222,  29.88888889,  23.57777778,
#         31.46666667,  25.78666667,  31.46666667,  22.63111111,
#         27.99555556,  24.20888889,  30.52      ,  25.47111111,
#         32.41333333,  22.94666667,  32.41333333,  23.57777778,
#         31.46666667,  23.89333333,  24.84      ,  34.62222222,
#         27.04888889,  23.57777778,  28.31111111,  26.73333333,
#         30.52      ,  29.88888889,  30.83555556,  25.78666667,
#         25.15555556,  32.72888889,  23.89333333,  23.26222222,
#         25.78666667,  27.99555556,  24.52444444,  24.52444444,
#         30.52      ,  24.20888889,  25.78666667,  29.25777778,
#         25.78666667,  23.26222222,  30.52      ,  24.20888889,
#         30.83555556,  25.47111111,  24.52444444,  28.31111111,
#         24.84      ,  24.84      ,  34.62222222,  25.47111111,
#         32.09777778,  24.84      ,  29.88888889,  17.58222222,
#         27.68      ,  26.41777778,  29.57333333,  26.10222222,
#         34.93777778,  26.73333333,  23.89333333,  22.31555556,
#         26.73333333,  32.94583333,  24.84      ,  29.88888889,
#         26.41777778,  25.78666667,  22.94666667,  23.89333333,
#         29.57333333,  26.10222222,  25.15555556,  29.88888889,
#         28.94222222,  27.68      ,  23.89333333,  28.94222222,
#         25.78666667,  21.05333333,  24.84      ,  30.20444444,
#         26.10222222,  24.20888889,  30.20444444,  23.89333333,
#         24.52444444,  29.88888889,  30.20444444,  23.89333333,
#         31.15111111,  25.15555556,  31.46666667,  23.26222222,
#         26.10222222,  29.88888889,  31.15111111,  23.57777778,
#         33.67555556,  24.84      ,  30.52      ,  25.15555556,
#         24.52444444,  28.31111111,  35.25333333,  24.52444444,
#         32.41333333,  23.89333333,  31.46666667,  27.99555556,
#         31.78222222,  24.20888889,  23.89333333,  28.94222222,
#         27.36444444,  29.57333333,  26.10222222,  29.57333333,
#         26.73333333,  22.63111111,  31.46666667,  23.26222222,
#         31.78222222,  24.84      ,  25.15555556,  27.04888889,
#         25.78666667,  23.89333333,  30.52      ,  24.52444444,
#         39.98666667,  23.57777778,  25.15555556,  22.        ,
#         25.47111111,  23.26222222,  28.62666667,  24.20888889,
#         25.78666667,  27.99555556,  32.41333333,  23.89333333,
#         32.41333333,  25.15555556,  36.51555556,  24.20888889,
#         31.78222222,  22.8875    ,  24.52444444,  32.09777778,
#         26.73333333,  28.62666667,  24.20888889,  24.84      ,
#         23.89333333,  30.20444444,  26.10222222,  23.57777778,
#         29.57333333,  23.57777778,  24.84      ,  22.94666667,
#         29.88888889,  24.52444444,  24.20888889,  29.88888889,
#         26.73333333,  29.25777778,  26.10222222,  29.88888889,
#         29.25777778,  25.47111111,  32.41333333,  23.57777778,
#         30.83555556,  25.78666667,  31.78222222,  23.26222222,
#         31.15111111,  31.15111111,  31.46666667,  23.57777778,
#         25.47111111,  30.83555556,  25.78666667,  35.56888889,
#         25.78666667,  30.20444444,  25.78666667,  29.25777778,
#         25.78666667,  29.88888889,  27.04888889,  24.52444444,
#         29.88888889,  26.10222222,  29.57333333,  23.57777778,
#         25.15555556,  23.26222222,  30.83555556,  25.47111111,
#         22.63111111,  23.26222222,  31.46666667,  24.20888889,
#         29.25777778,  23.89333333,  23.89333333,  27.99555556,
#         24.52444444,  30.83555556,  30.83555556,  30.83555556,
#         30.83555556,  26.41777778,  29.88888889,  25.15555556,
#         23.89333333,  28.94222222,  29.57333333,  26.41777778,
#         28.2125    ,  23.57777778,  24.20888889,  29.57333333,
#         30.20444444,  24.84      ,  31.46666667,  26.41777778,
#         28.94222222,  28.31111111,  26.73333333,  23.57777778,
#         31.15111111,  24.84      ,  30.52      ,  25.78666667,
#         29.88888889,  25.15555556,  30.20444444,  25.78666667,
#         29.57333333,  26.10222222,  24.84      ,  28.31111111])

# %%
plt.subplots(figsize=(30, 10))
tmps = np.arange(len(h))

X_mean = np.asarray(pd.rolling_mean(df['valeur'],5))


plt.plot(tmps,h,color='indianred',alpha=0.5)
plt.plot(tmps,y_arr[:len(h)],alpha=0.5)

# %%
h;

# %%
h_out = np.zeros(len(h)+window)
for i in range(len(h)):
    if i >= window:
        h_out[i] = h[i]
    else:
        h_out[i] = 0
df_slice['time'] = np.arange(df_slice.time.size)
# Out:
# /home/jaafar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
I = np.arange(h_out.size)
df2 = DataFrame(h_out,I,columns=['pred'])
df_resultat = pd.merge(df_slice,df2,right_index=True,left_on='time')#,left_on=True,right_on=True)
df_resultat;

# %%
df_resultat[['valeur','pred']].plot(subplots=False,figsize=(20,5))
