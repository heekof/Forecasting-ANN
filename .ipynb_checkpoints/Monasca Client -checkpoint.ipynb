# %%
import datetime
import time

# Import libraries use for visualization and analysis
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import cufflinks as cf

from monascaclient import client
from monascaclient import ksclient

from pandas import Series,DataFrame

import math
from __future__ import division

# Import library to execute remote commands for monasca-agent demo
import spur
import matplotlib.pyplot as plt
import seaborn as sns

from my_functions import *

# %%
monasca_connect(ksclient,client)

# %%
monasca_connect(ksclient)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-be7dff491a11> in <module>()
# ----> 1 monasca_connect(ksclient)
#
# TypeError: monasca_connect() takes no arguments (1 given)

# %%
#measurements = get_measurements(metrics,"2016-05-10T15:52:26.0Z","2016-05-20T15:55:26.0Z")

# %%
metrics = get_metrics(names=['net.out_packets_sec'])
measurements = get_measurements(metrics,"2016-05-10T15:52:26.0Z","2016-05-20T15:55:26.0Z")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-57fd2708c436> in <module>()
# ----> 1 metrics = get_metrics(names=['net.out_packets_sec'])
#       2 measurements = get_measurements(metrics,"2016-05-10T15:52:26.0Z","2016-05-20T15:55:26.0Z")
#
# NameError: name 'get_metrics' is not defined

# %%
#monasca_client.metrics.list_measurements('2014-01-01T00:00:00Z');

# %%
#shell = spur.SshShell(hostname='157.159.232.217',username='ubuntu',missing_host_key=spur.ssh.MissingHostKey.accept,private_key_file='/home/jaafar/Downloads/ici.pem');

# %%
# for testing
#T = shell.run(["ifconfig"])

# %%
#T = shell.run(["monasca","measurement-list","cpu.user_perc", "2016-05-20T15:52:26.0C"])

# %%
#result = shell.run(["export", "OS_PROJECT_NAME=mini-mon"])#,["export", "OS_PASSWORD=password"],["export", "OS_AUTH_URL=http://157.159.232.218:35357/v3"],["export", "OS_USERNAME=mini-mon"])#
#print(result.output) # prints hello

# %%
#result = shell.run(["monasca","metric-list"])
#print(result.output) # prints hello

# %%
# sync clock
# shell.run(['sudo', 'ntpdate', 'time.nist.gov'])

# %%
#sns.lmplot('time','valeur',df,order=2,scatter_kws={'marker':'o','color':'indianred'},line_kws={'linewidth':1,'color':'blue'})

# %% [markdown]
# ## Start from Here the Evaluation

# %%
# test 
Z = np.arange(100)
i = 0;
X = np.zeros(x.size)
for a in Z:
    X[i] = math.sin(a)
    i = i + 1;
X;

# %%
v = np.asarray(df.valeur)

a = 10
X = v[1:a]
#X = X_mean[1:20];
df_slice = df[1:a];
df_slice;
X_mean = np.asarray(pd.rolling_mean(df_slice['valeur'],3))

# %%
write_to_csv('jaafar.csv',df)

# %%
# Plot the selected sub range in function of time 
tmps =np.arange(X.size)
plt.subplots(figsize=(30, 10))
plt.plot(tmps,X,color='indianred',alpha=0.5)

# %%
# We'll use pct_change to find the percent change for each day
df_slice['perc_change'] = df_slice['valeur'].pct_change()
# Then we'll plot the daily return percentage
df_slice['valeur'].plot(figsize=(16,6),legend=True,linestyle='-',marker='o')

df_slice['perc_change'].plot(figsize=(16,6),legend=True,linestyle='-',marker='x')
# Out:
# /home/jaafar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#X = perc_change;

#X = X[~np.isnan(X)]
X;

# %%
ma_pt = [2,10]

for ma in ma_pt:
    column_name = "MA for %s datapoint" %(str(ma))
    df_slice[column_name]=pd.rolling_mean(df_slice['valeur'],ma)
# Out:
# /home/jaafar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_slice[['valeur','MA for 10 datapoint']].plot(subplots=True,figsize=(20,5),)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f63b62093d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63b60c70d0>], dtype=object)

# %%
#[X_norm,normx,normy] = normalize(X)
X_norm = normalize(X)
X_perc = percentage_change(X)
X_rol_avg = rolling_avg(X,3)
X_norm.sum()
# Out:
# 1.0

# %%
window = 1
step_size = 2
[X_vect,y_vect,y_arr] = structure_data(X_norm,window,1)

# %%
X_vect
# Out:
# [[0.22206703910614525],
#  [0.10474860335195531],
#  [0.081005586592178769],
#  [0.10754189944134079],
#  [0.09217877094972067],
#  [0.10335195530726257],
#  [0.10893854748603352]]

# %%
from ann import ANN

# 1,10,20,1 
nn = ANN([window,10,20,50,1], activation_fun='linear')


# Here please Try to represent the input data as percentage so that you can capture patterns

# train the ANN
#nn.train(inputs, targets, 1600)
nn.train(X_vect,y_vect,2000)
# Out:
# (0, 0.032006356537823057)
# (100, 0.0005965361179953142)
# (200, 0.00058663625061266915)
# (300, 0.00057748846101036012)
# (400, 0.00056896313037111876)
# (500, 0.00056091101017261404)
# (600, 0.00055331613532598424)
# (700, 0.00054643946469980307)
# (800, 0.00053990153062867985)
# (900, 0.00053354498964821348)
# (1000, 0.00052723298019614808)
# (1100, 0.00052111202885737949)
# (1200, 0.0005152539245524046)
# (1300, 0.00050951039057905913)
# (1400, 0.0005038463554174257)
# (1500, 0.00049840052227748924)
# (1600, 0.00049315780795524018)
# (1700, 0.00048810481781842366)
# (1800, 0.00048322964391144424)
# (1900, 0.00047852169023628272)

# %%
pred = np.zeros(v.size);
for i in range(v.size):
    pred[i] = (v[i] + nn.predict([v[i]])[0]*v[i])
df['prediction'] = pred

# %%
#X = v[1:a]
h = get_prediction(X,1)

# %%
y_arr = np.asanyarray(y_vect)
h_arr = np.asanyarray(h)
error = (y_arr - y_arr)**2
y_arr;

# %%
'''X_mean = np.asarray(pd.rolling_mean(df_slice['valeur'],5))
y_arr_N;'''

h_out = recadrer(pred,window);

#plot(h,y_vect,100);

tmps = np.arange(100)
plt.subplots(figsize=(30, 10))
plt.plot(tmps,pred[100:200],'r-',v[100:200],'b--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-e9b4d6f62cb6> in <module>()
#       2 y_arr_N;'''
#       3
# ----> 4 h_out = recadrer(pred,window);
#       5
#       6 #plot(h,y_vect,100);
#
# NameError: name 'recadrer' is not defined

# %%
#df.to_csv('data.csv',sep=';')
df = pd.read_csv('data.csv',sep=';');

# %%
cond = [ df.valeur.base > 6 ]
df['SLO_1 violation'] = cond[0][0]

# %%
#df[['prediction','valeur']][1:10].plot(title="my title")
#sns.lmplot('time','valeur',df[1:20],scatter_kws={'marker':'o','color':'indianred'},fit_reg=False,line_kws={'linewidth':1,'color':'blue'})
#df[0:20].plot.scatter('time', 'valeur')
#df[0:20].plot.scatter('time', 'prediction')
'''subplots = False
df[1:10].plot('time','prediction',title="my title",kind='scatter',subplots=False)
df[1:10].plot('time','valeur',title="my title",kind='scatter',subplots=False)'''



ax = df[1:20].plot.scatter(x='time', y='valeur', color='DarkBlue', label='Actual values');
df[1:20].plot.scatter(x='time', y='prediction', color='DarkGreen', label='Predicted values', ax=ax);

# %%
g = sns.lmplot(x="time", y="valeur", col="day", hue="day",
...                data=tips, col_wrap=2, size=3)
# Out:
# Help on method scatter in module pandas.tools.plotting:
#
# scatter(self, x, y, s=None, c=None, **kwds) method of pandas.tools.plotting.FramePlotMethods instance
#     Scatter plot
#
#     .. versionadded:: 0.17.0
#
#     Parameters
#     ----------
#     x, y : label or position, optional
#         Coordinates for each point.
#     s : scalar or array_like, optional
#         Size of each point.
#     c : label or position, optional
#         Color of each point.
#     **kwds : optional
#         Keyword arguments to pass on to :py:meth:`pandas.DataFrame.plot`.
#
#     Returns
#     -------
#     axes : matplotlib.AxesSubplot or np.array of them

# %%
#df_slice[['valeur','prediction']].plot(subplots=False,figsize=(10,5),alpha=0.5)
sns.lmplot('time','valeur',df[1:100],fit_reg=False,hue='SLO_1 violation',robust=True,markers=['x','o'],ci=None, scatter_kws={"s": 80})

# %%
#df[['valeur','SLO_1 violation']][1:100].plot(subplots=False,figsize=(20,5))
sns.factorplot(data=df[30:50], x="time", y="valeur",col="name",hue="SLO_1 violation",size=3,aspect=2)
